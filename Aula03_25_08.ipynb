# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeFogolin/Estudos-Dados-FECAP/blob/main/Aula03_25_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 03 - 25/08/2025 - Projeto em Ciência de Dados

# %%
import pandas as pd
df = pd.read_csv("PETROLEO.txt", sep = ";")
df.head()
# Out:
#          DATA  VALOR
# 0  10/02/2025  76,23
# 1  07/02/2025  74,68
# 2  06/02/2025  74,54
# 3  05/02/2025  74,71
# 4  04/02/2025  76,58

# %%
df.query("DATA >= '01/01/2025'").sort_values(by = "DATA") # Ordenação errada, pois não é date
# Out:
#            DATA  VALOR
# 509  01/02/2023  81,61
# 258  01/02/2024  82,20
# 489  01/03/2023  83,68
# 237  01/03/2024  84,82
# 196  01/05/2024  83,55
# ..          ...    ...
# 383  31/07/2023  85,22
# 133  31/07/2024  81,39
# 361  31/08/2023  87,29
# 68   31/10/2024  73,25
# 28   31/12/2024  74,58
#
# [532 rows x 2 columns]

# %%
from datetime import datetime

# Formatação de data

data_str = "2025-08-25 19:25:20"
data_format = "%Y-%m-%d %H:%M:%S"
data = datetime.strptime(data_str, data_format)
print(data)
# Out:
# 2025-08-25 19:25:20
# 2025-08-25 19:25:20
